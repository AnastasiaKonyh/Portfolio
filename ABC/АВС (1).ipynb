# %% [markdown]
# __Задача анализа разделить товары на группы по принципу:__
#
# - А — наиболее ценные, 20% — ассортимента (номенклатура); 80% — продаж
# - В — промежуточные, 30% — ассортимента; 15% — продаж
# - С — наименее ценные, 50% — ассортимента; 5% — продаж

# %% [markdown]
# Данные для работы хранятся в PostgreSQL

# %%
from postgresql_secret import pg_secret

# %% [markdown]
# Создала соеденение

# %%
import psycopg2

connection = psycopg2.connect(
                             database=pg_secret['db_name'],
                             user=pg_secret['db_user'],
                             password=pg_secret['db_password'],
                             host=pg_secret['db_host'],
                             port=pg_secret['db_port'],
                             )

cursor = connection.cursor()#курсор, чтобы делать запросы в базу

# %%
import pandas as pd

query = "SELECT * FROM products" 
cursor.execute(query)
result = cursor.fetchall()
cursor.description
columns = []
for desc in cursor.description:
    columns.append(desc[0])


products = pd.DataFrame(result, columns = columns)
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 779495 entries, 0 to 779494
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   invoice_id   779495 non-null  int64
#  1   stock_code   779495 non-null  object
#  2   description  779495 non-null  object
#  3   quantity     779495 non-null  int64
#  4   price        779495 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 29.7+ MB

# %%
products['invoice_id'] = products['invoice_id'].apply(str)
products['price'] = products['price'].astype('float64')
products.head()
# Out:
#   invoice_id stock_code                       description  quantity  price
# 0     513762      21913    VINTAGE SEASIDE JIGSAW PUZZLES         4   3.75
# 1     513762      21914            BLUE HARMONICA IN BOX         12   1.25
# 2     513762      21918  SET 12 KIDS COLOUR  CHALK STICKS        24   0.42
# 3     513762      21931            JUMBO STORAGE BAG SUKI        10   1.95
# 4     513762      21975    PACK OF 60 DINOSAUR CAKE CASES        24   0.55

# %% [markdown]
# Посчитала, какой доход принес каждый продукт и сколько единиц каждого продукта было продано

# %%
products['total'] = products['quantity']*products['price']
products.head()
# Out:
#   invoice_id stock_code                       description  quantity  price  \
# 0     513762      21913    VINTAGE SEASIDE JIGSAW PUZZLES         4   3.75
# 1     513762      21914            BLUE HARMONICA IN BOX         12   1.25
# 2     513762      21918  SET 12 KIDS COLOUR  CHALK STICKS        24   0.42
# 3     513762      21931            JUMBO STORAGE BAG SUKI        10   1.95
# 4     513762      21975    PACK OF 60 DINOSAUR CAKE CASES        24   0.55
#
#    total
# 0  15.00
# 1  15.00
# 2  10.08
# 3  19.50
# 4  13.20

# %%
products_total = products.groupby(['stock_code', 'description'])['total'].sum().reset_index()
products_total
# общий доход по каждому товару
# Out:
#      stock_code                  description      total
# 0         10002  INFLATABLE POLITICAL GLOBE     6638.27
# 1         10080     GROOVY CACTUS INFLATABLE     124.61
# 2         10109         BENDY COLOUR PENCILS       1.68
# 3         10120                 DOGGY RUBBER     136.08
# 4        10123C        HEARTS WRAPPING TAPE      226.76
# ...         ...                          ...        ...
# 5310       PADS   PADS TO MATCH ALL CUSHIONS       0.00
# 5311       POST                      POSTAGE  124648.04
# 5312     SP1002       KID'S CHALKBOARD/EASEL      14.75
# 5313    TEST001      This is a test product.     225.00
# 5314    TEST002      This is a test product.       1.00
#
# [5315 rows x 3 columns]

# %%
products_count = products.groupby('stock_code')['quantity'].sum().reset_index()
products_count
# общее количество проданных единиц по каждому товару
# Out:
#      stock_code  quantity
# 0         10002      8479
# 1         10080       303
# 2         10109         4
# 3         10120       648
# 4        10123C       628
# ...         ...       ...
# 4626       PADS        18
# 4627       POST      5235
# 4628     SP1002         5
# 4629    TEST001        60
# 4630    TEST002         1
#
# [4631 rows x 2 columns]

# %%
products = pd.merge(products_total, products_count, on = 'stock_code', how = 'left')
products
#объеденяем данные в одну таблицу
# Out:
#      stock_code                  description      total  quantity
# 0         10002  INFLATABLE POLITICAL GLOBE     6638.27      8479
# 1         10080     GROOVY CACTUS INFLATABLE     124.61       303
# 2         10109         BENDY COLOUR PENCILS       1.68         4
# 3         10120                 DOGGY RUBBER     136.08       648
# 4        10123C        HEARTS WRAPPING TAPE      226.76       628
# ...         ...                          ...        ...       ...
# 5310       PADS   PADS TO MATCH ALL CUSHIONS       0.00        18
# 5311       POST                      POSTAGE  124648.04      5235
# 5312     SP1002       KID'S CHALKBOARD/EASEL      14.75         5
# 5313    TEST001      This is a test product.     225.00        60
# 5314    TEST002      This is a test product.       1.00         1
#
# [5315 rows x 4 columns]

# %% [markdown]
# __Находим нарастающий итог по процентам__

# %%
products.sort_values(by='total', ascending=False)
products
# Out:
#      stock_code                         description      total  quantity
# 1862      22423            REGENCY CAKESTAND 3 TIER  277656.25     24139
# 4751     85123A  WHITE HANGING HEART T-LIGHT HOLDER  247048.01     91814
# 3283      23843         PAPER CRAFT , LITTLE BIRDIE  168469.60     80995
# 5309          M                              Manual  151777.67      9391
# 4725     85099B             JUMBO BAG RED RETROSPOT  134307.44     93436
# ...         ...                                 ...        ...       ...
# 4042     84206B         CAT W SUNGLASSES BLANK CARD       0.76         9
# 3015      23366     SET 12 COLOURING PENCILS DOILEY       0.65      1919
# 3406      35930     PINK HEART CHRISTMAS DECORATION       0.38         1
# 4040     84205C      HAPPY BIRTHDAY GINGER CAT CARD       0.38         2
# 5310       PADS          PADS TO MATCH ALL CUSHIONS       0.00        18
#
# [5315 rows x 4 columns]

# %%
products['percent_total'] = round((products['total']/round(products['total'].sum()))*100,2)
products
# процент дохода для каждого товара
# Out:
#      stock_code                         description      total  quantity  \
# 1862      22423            REGENCY CAKESTAND 3 TIER  277656.25     24139
# 4751     85123A  WHITE HANGING HEART T-LIGHT HOLDER  247048.01     91814
# 3283      23843         PAPER CRAFT , LITTLE BIRDIE  168469.60     80995
# 5309          M                              Manual  151777.67      9391
# 4725     85099B             JUMBO BAG RED RETROSPOT  134307.44     93436
# ...         ...                                 ...        ...       ...
# 4042     84206B         CAT W SUNGLASSES BLANK CARD       0.76         9
# 3015      23366     SET 12 COLOURING PENCILS DOILEY       0.65      1919
# 3406      35930     PINK HEART CHRISTMAS DECORATION       0.38         1
# 4040     84205C      HAPPY BIRTHDAY GINGER CAT CARD       0.38         2
# 5310       PADS          PADS TO MATCH ALL CUSHIONS       0.00        18
#
#       percent_total
# 1862           1.60
# 4751           1.42
# 3283           0.97
# 5309           0.87
# 4725           0.77
# ...             ...
# 4042           0.00
# 3015           0.00
# 3406           0.00
# 4040           0.00
# 5310           0.00
#
# [5315 rows x 5 columns]

# %%
products['running_total_percent'] = round (products['percent_total'].cumsum(),2)
products
#кумулятивная сумма
# Out:
#      stock_code                         description      total  quantity  \
# 1862      22423            REGENCY CAKESTAND 3 TIER  277656.25     24139
# 4751     85123A  WHITE HANGING HEART T-LIGHT HOLDER  247048.01     91814
# 3283      23843         PAPER CRAFT , LITTLE BIRDIE  168469.60     80995
# 5309          M                              Manual  151777.67      9391
# 4725     85099B             JUMBO BAG RED RETROSPOT  134307.44     93436
# ...         ...                                 ...        ...       ...
# 4042     84206B         CAT W SUNGLASSES BLANK CARD       0.76         9
# 3015      23366     SET 12 COLOURING PENCILS DOILEY       0.65      1919
# 3406      35930     PINK HEART CHRISTMAS DECORATION       0.38         1
# 4040     84205C      HAPPY BIRTHDAY GINGER CAT CARD       0.38         2
# 5310       PADS          PADS TO MATCH ALL CUSHIONS       0.00        18
#
#       percent_total  running_total_percent
# 1862           1.60                   1.60
# 4751           1.42                   3.02
# 3283           0.97                   3.99
# 5309           0.87                   4.86
# 4725           0.77                   5.63
# ...             ...                    ...
# 4042           0.00                  97.33
# 3015           0.00                  97.33
# 3406           0.00                  97.33
# 4040           0.00                  97.33
# 5310           0.00                  97.33
#
# [5315 rows x 6 columns]

# %% [markdown]
# __Помечаем товары метками `'A'`, `'B'`, `'C'` в зависимости от нарастающего итога__

# %%
def revenue(x):
    if x <=80:
        return 'A'
    if x <=95:
        return 'B'
    else:
        return 'C'
    # допиши функцию
products['revenue'] = products['running_total_percent'].apply(revenue)
products

#  новый столбец revenue
# Out:
#      stock_code                         description      total  quantity  \
# 1862      22423            REGENCY CAKESTAND 3 TIER  277656.25     24139
# 4751     85123A  WHITE HANGING HEART T-LIGHT HOLDER  247048.01     91814
# 3283      23843         PAPER CRAFT , LITTLE BIRDIE  168469.60     80995
# 5309          M                              Manual  151777.67      9391
# 4725     85099B             JUMBO BAG RED RETROSPOT  134307.44     93436
# ...         ...                                 ...        ...       ...
# 4042     84206B         CAT W SUNGLASSES BLANK CARD       0.76         9
# 3015      23366     SET 12 COLOURING PENCILS DOILEY       0.65      1919
# 3406      35930     PINK HEART CHRISTMAS DECORATION       0.38         1
# 4040     84205C      HAPPY BIRTHDAY GINGER CAT CARD       0.38         2
# 5310       PADS          PADS TO MATCH ALL CUSHIONS       0.00        18
#
#       percent_total  running_total_percent revenue
# 1862           1.60                   1.60       A
# 4751           1.42                   3.02       A
# 3283           0.97                   3.99       A
# 5309           0.87                   4.86       A
# 4725           0.77                   5.63       A
# ...             ...                    ...     ...
# 4042           0.00                  97.33       C
# 3015           0.00                  97.33       C
# 3406           0.00                  97.33       C
# 4040           0.00                  97.33       C
# 5310           0.00                  97.33       C
#
# [5315 rows x 7 columns]

# %% [markdown]
# __Находим нарастающий итог по количеству товарных единиц и пометь товары метками `'A'`, `'B'`, `'C'`, отмечая тем самым популярность товара__

# %%
products = products.sort_values(by='quantity', ascending = False)
products
# Out:
#      stock_code                          description      total  quantity  \
# 4031      84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS   24098.03    105185
# 4727     85099B             RED RETROSPOT JUMBO BAG     9289.35     93436
# 4726     85099B          JUMBO BAG RED WHITE SPOTTY    24323.85     93436
# 4725     85099B              JUMBO BAG RED RETROSPOT  134307.44     93436
# 4750     85123A   CREAM HANGING HEART T-LIGHT HOLDER     155.35     91814
# ...         ...                                  ...        ...       ...
# 855       21409             SPOTTY COCKEREL DOORSTOP       4.25         1
# 3794     72751C         F.FAIRY S/3 SML CANDLE, ROSE       5.95         1
# 4904     90000C    OPAL WHITE/SILVER FLOWER NECKLACE       5.95         1
# 3792     72751A   F.FAIRY S/3 SML CANDLE,LILY/VALLEY       5.95         1
# 3795     72752A  F.FAIRY,CANDLE IN GLASS,LILY/VALLEY       4.25         1
#
#       percent_total  running_total_percent revenue
# 4031           0.14                  29.60       A
# 4727           0.05                  57.94       A
# 4726           0.14                  28.62       A
# 4725           0.77                   5.63       A
# 4750           0.00                  97.33       C
# ...             ...                    ...     ...
# 855            0.00                  97.33       C
# 3794           0.00                  97.33       C
# 4904           0.00                  97.33       C
# 3792           0.00                  97.33       C
# 3795           0.00                  97.33       C
#
# [5315 rows x 7 columns]

# %%
products['percent_quantity']= round((products['quantity']/products['quantity'].sum())*100,2)
products
# Out:
#      stock_code                          description      total  quantity  \
# 4031      84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS   24098.03    105185
# 4727     85099B             RED RETROSPOT JUMBO BAG     9289.35     93436
# 4726     85099B          JUMBO BAG RED WHITE SPOTTY    24323.85     93436
# 4725     85099B              JUMBO BAG RED RETROSPOT  134307.44     93436
# 4750     85123A   CREAM HANGING HEART T-LIGHT HOLDER     155.35     91814
# ...         ...                                  ...        ...       ...
# 855       21409             SPOTTY COCKEREL DOORSTOP       4.25         1
# 3794     72751C         F.FAIRY S/3 SML CANDLE, ROSE       5.95         1
# 4904     90000C    OPAL WHITE/SILVER FLOWER NECKLACE       5.95         1
# 3792     72751A   F.FAIRY S/3 SML CANDLE,LILY/VALLEY       5.95         1
# 3795     72752A  F.FAIRY,CANDLE IN GLASS,LILY/VALLEY       4.25         1
#
#       percent_total  running_total_percent revenue  percent_quantity
# 4031           0.14                  29.60       A              0.77
# 4727           0.05                  57.94       A              0.69
# 4726           0.14                  28.62       A              0.69
# 4725           0.77                   5.63       A              0.69
# 4750           0.00                  97.33       C              0.68
# ...             ...                    ...     ...               ...
# 855            0.00                  97.33       C              0.00
# 3794           0.00                  97.33       C              0.00
# 4904           0.00                  97.33       C              0.00
# 3792           0.00                  97.33       C              0.00
# 3795           0.00                  97.33       C              0.00
#
# [5315 rows x 8 columns]

# %%
products['running_percent_quantity'] = round(products['percent_quantity'].cumsum(),2)
products
# Out:
#      stock_code                          description      total  quantity  \
# 4031      84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS   24098.03    105185
# 4727     85099B             RED RETROSPOT JUMBO BAG     9289.35     93436
# 4726     85099B          JUMBO BAG RED WHITE SPOTTY    24323.85     93436
# 4725     85099B              JUMBO BAG RED RETROSPOT  134307.44     93436
# 4750     85123A   CREAM HANGING HEART T-LIGHT HOLDER     155.35     91814
# ...         ...                                  ...        ...       ...
# 855       21409             SPOTTY COCKEREL DOORSTOP       4.25         1
# 3794     72751C         F.FAIRY S/3 SML CANDLE, ROSE       5.95         1
# 4904     90000C    OPAL WHITE/SILVER FLOWER NECKLACE       5.95         1
# 3792     72751A   F.FAIRY S/3 SML CANDLE,LILY/VALLEY       5.95         1
# 3795     72752A  F.FAIRY,CANDLE IN GLASS,LILY/VALLEY       4.25         1
#
#       percent_total  running_total_percent revenue  percent_quantity  \
# 4031           0.14                  29.60       A              0.77
# 4727           0.05                  57.94       A              0.69
# 4726           0.14                  28.62       A              0.69
# 4725           0.77                   5.63       A              0.69
# 4750           0.00                  97.33       C              0.68
# ...             ...                    ...     ...               ...
# 855            0.00                  97.33       C              0.00
# 3794           0.00                  97.33       C              0.00
# 4904           0.00                  97.33       C              0.00
# 3792           0.00                  97.33       C              0.00
# 3795           0.00                  97.33       C              0.00
#
#       running_percent_quantity
# 4031                      0.77
# 4727                      1.46
# 4726                      2.15
# 4725                      2.84
# 4750                      3.52
# ...                        ...
# 855                      98.05
# 3794                     98.05
# 4904                     98.05
# 3792                     98.05
# 3795                     98.05
#
# [5315 rows x 9 columns]

# %%
def quantity(x):
    if x <=80:
        return 'A'
    elif x<=95:
        return 'B'
    else:
        return 'C'
    
products['popularity'] = products ['running_percent_quantity'].apply(quantity)


# новый столбец popularity

# %%
products.head()
# Out:
#      stock_code                         description      total  quantity  \
# 4031      84077   WORLD WAR 2 GLIDERS ASSTD DESIGNS   24098.03    105185
# 4727     85099B            RED RETROSPOT JUMBO BAG     9289.35     93436
# 4726     85099B         JUMBO BAG RED WHITE SPOTTY    24323.85     93436
# 4725     85099B             JUMBO BAG RED RETROSPOT  134307.44     93436
# 4750     85123A  CREAM HANGING HEART T-LIGHT HOLDER     155.35     91814
#
#       percent_total  running_total_percent revenue  percent_quantity  \
# 4031           0.14                  29.60       A              0.77
# 4727           0.05                  57.94       A              0.69
# 4726           0.14                  28.62       A              0.69
# 4725           0.77                   5.63       A              0.69
# 4750           0.00                  97.33       C              0.68
#
#       running_percent_quantity popularity
# 4031                      0.77          A
# 4727                      1.46          A
# 4726                      2.15          A
# 4725                      2.84          A
# 4750                      3.52          A

# %% [markdown]
# __Объединяем группы и анализируем__

# %%
products['group'] = products['revenue']+products['popularity']
products.head()
# Out:
#      stock_code                         description      total  quantity  \
# 4031      84077   WORLD WAR 2 GLIDERS ASSTD DESIGNS   24098.03    105185
# 4727     85099B            RED RETROSPOT JUMBO BAG     9289.35     93436
# 4726     85099B         JUMBO BAG RED WHITE SPOTTY    24323.85     93436
# 4725     85099B             JUMBO BAG RED RETROSPOT  134307.44     93436
# 4750     85123A  CREAM HANGING HEART T-LIGHT HOLDER     155.35     91814
#
#       percent_total  running_total_percent revenue  percent_quantity  \
# 4031           0.14                  29.60       A              0.77
# 4727           0.05                  57.94       A              0.69
# 4726           0.14                  28.62       A              0.69
# 4725           0.77                   5.63       A              0.69
# 4750           0.00                  97.33       C              0.68
#
#       running_percent_quantity popularity group
# 4031                      0.77          A    AA
# 4727                      1.46          A    AA
# 4726                      2.15          A    AA
# 4725                      2.84          A    AA
# 4750                      3.52          A    CA

# %%
products['group'].value_counts()
# Out:
# CC    2334
# AA     765
# BB     528
# BC     441
# CB     433
# BA     278
# AB     269
# CA     157
# AC     110
# Name: group, dtype: int64

# %% [markdown]
# __Выгружаем данные по товарам с метокой по ABC-анализу__

# %%
products = products[['stock_code', 'description', 'group']]
products
# Out:
#      stock_code                          description group
# 4031      84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS    AA
# 4727     85099B             RED RETROSPOT JUMBO BAG     AA
# 4726     85099B          JUMBO BAG RED WHITE SPOTTY     AA
# 4725     85099B              JUMBO BAG RED RETROSPOT    AA
# 4750     85123A   CREAM HANGING HEART T-LIGHT HOLDER    CA
# ...         ...                                  ...   ...
# 855       21409             SPOTTY COCKEREL DOORSTOP    CC
# 3794     72751C         F.FAIRY S/3 SML CANDLE, ROSE    CC
# 4904     90000C    OPAL WHITE/SILVER FLOWER NECKLACE    CC
# 3792     72751A   F.FAIRY S/3 SML CANDLE,LILY/VALLEY    CC
# 3795     72752A  F.FAIRY,CANDLE IN GLASS,LILY/VALLEY    CC
#
# [5315 rows x 3 columns]

# %%
products.to_csv('products.csv', index=False)
